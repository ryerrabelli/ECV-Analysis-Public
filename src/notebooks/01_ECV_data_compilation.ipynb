# %% [markdown]
# # Setup

# %%
#@title ## Base imports
import os
import cmd
import sys
import json
import numpy as np
import pandas as pd
import scipy
import scipy.stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

import sklearn.metrics

import skimage
import skimage.io
import PIL
import PIL.Image
import requests

import IPython.display
import matplotlib
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots

# Display versions of python packages
pip_versions = %system pip freeze  # uses colab magic to get list from shell
pip_versions_organized = {
    "standard": [pip_version for pip_version in pip_versions if "==" in pip_version],
    "other": [pip_version for pip_version in pip_versions if "==" not in pip_version]
    }
print(f"Python version: {sys.version} \n")  # display version of python itself (i.e. 3.8.10)
cli = cmd.Cmd()
cli.columnize(pip_versions_organized["standard"], displaywidth=800)
cli.columnize(pip_versions_organized["other"], displaywidth=160)
# Out:
# Python version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#
# absl-py==1.4.0                autograd==1.6.2         cffi==1.16.0               contourpy==1.2.1       distro==1.7.0             fastcore==1.5.48        gcsfs==2023.6.0                      google-cloud-aiplatform==1.57.0           google-resumable-media==2.7.1     httplib2==0.22.0            ipyevents==2.0.2         jsonschema==4.19.2                    lazy_loader==0.4            mdurl==0.1.2             nbclassic==1.1.0                 opencv-python-headless==4.10.0.84  patsy==0.5.6               prometheus_client==0.20.0  pydantic_core==2.20.0      pyperclip==1.9.0        qudida==0.0.4               seaborn==0.13.1          spacy-loggers==1.0.5                   tbb==2021.13.0                        tf_keras==2.15.1      typer==0.12.3                      widgetsnbextension==3.6.6
# aiohttp==3.9.5                Babel==2.15.0           chardet==5.2.0             cryptography==42.0.8   dlib==19.24.4             fastdownload==0.0.7     GDAL==3.6.4                          google-cloud-bigquery==3.21.0             googleapis-common-protos==1.63.2  huggingface-hub==0.23.4     ipyfilechooser==0.6.0    jsonschema-specifications==2023.12.1  libclang==18.1.1            miniKanren==1.0.3        nbclient==0.10.0                 openpyxl==3.1.5                    peewee==3.17.5             promise==2.3               pydata-google-auth==1.8.2  pyproj==3.6.1           ratelim==0.1.6              SecretStorage==3.3.1     Sphinx==5.0.2                          tblib==3.0.0                          thinc==8.2.5          types-pytz==2024.1.0.20240417      wordcloud==1.9.3
# aiosignal==1.3.1              backcall==0.2.0         charset-normalizer==3.3.2  cuda-python==12.2.1    dm-tree==0.1.8            fastjsonschema==2.20.0  gdown==5.1.0                         google-cloud-bigquery-connection==1.12.1  googledrivedownloader==0.4        humanize==4.7.0             ipykernel==5.5.6         jupyter-client==6.1.12                librosa==0.10.2.post1       missingno==0.5.2         nbconvert==6.5.4                 opt-einsum==3.3.0                  pexpect==4.9.0             prompt_toolkit==3.0.47     pydot==1.4.2               pyproject_hooks==1.1.0  referencing==0.35.1         Send2Trash==1.8.3        sphinxcontrib-applehelp==1.0.8         tenacity==8.4.2                       threadpoolctl==3.5.0  types-setuptools==70.1.0.20240627  wrapt==1.14.1
# alabaster==0.7.16             beautifulsoup4==4.12.3  chex==0.1.86               cufflinks==0.17.3      docstring_parser==0.16    fastprogress==1.0.3     geemap==0.32.1                       google-cloud-bigquery-storage==2.25.0     graphviz==0.20.3                  hyperopt==0.2.7             ipyleaflet==0.18.2       jupyter-console==6.1.0                lightgbm==4.1.0             mistune==0.8.4           nbformat==5.10.4                 optax==0.2.2                       pickleshare==0.7.5         prophet==1.1.5             pydot-ng==2.0.0            pyshp==2.3.1            regex==2024.5.15            sentencepiece==0.1.99    sphinxcontrib-devhelp==1.0.6           tensorboard==2.15.2                   tifffile==2024.6.18   typing_extensions==4.12.2          xarray==2023.7.0
# albumentations==1.3.1         bidict==0.23.1          click==8.1.7               cupy-cuda12x==12.2.0   docutils==0.18.1          fastrlock==0.8.2        gensim==4.3.2                        google-cloud-bigtable==2.24.0             greenlet==3.0.3                   ibis-framework==8.0.0       ipyparallel==8.8.0       jupyter-server==1.24.0                linkify-it-py==2.0.3        mizani==0.9.3            nest-asyncio==1.6.0              orbax-checkpoint==0.4.4            Pillow==9.4.0              proto-plus==1.24.0         pydotplus==2.0.2           PySocks==1.7.1          requests==2.31.0            shapely==2.0.4           sphinxcontrib-htmlhelp==2.0.5          tensorboard-data-server==0.7.2        tinycss2==1.3.0       tzdata==2024.1                     xarray-einstats==0.7.0
# altair==4.2.2                 bigframes==1.11.0       click-plugins==1.1.1       cvxopt==1.3.2          dopamine_rl==4.0.9        filelock==3.15.4        geocoder==1.38.1                     google-cloud-core==2.3.3                  grpc-google-iam-v1==0.13.1        idna==3.7                   ipython==7.34.0          jupyter_core==5.7.2                   llvmlite==0.41.1            mkl==2023.2.0            networkx==3.3                    osqp==0.6.2.post8                  pip-tools==6.13.0          protobuf==3.20.3           PyDrive==1.3.1             pytensor==2.18.6        requests-oauthlib==1.3.1    shellingham==1.5.4       sphinxcontrib-jsmath==1.0.1            tensorflow-datasets==4.9.6            tokenizers==0.19.1    tzlocal==5.2                       xgboost==2.0.3
# annotated-types==0.7.0        bleach==6.1.0           cligj==0.7.2               cvxpy==1.3.4           duckdb==0.10.3            fiona==1.9.6            geographiclib==2.0                   google-cloud-datastore==2.15.2            grpcio==1.64.1                    imageio==2.31.6             ipython-genutils==0.2.0  jupyterlab_pygments==0.3.0            locket==1.0.0               ml-dtypes==0.2.0         nibabel==4.0.2                   packaging==24.1                    platformdirs==4.2.2        psutil==5.9.5              PyDrive2==1.6.3            pytest==7.4.4           requirements-parser==0.9.0  simple_parsing==0.1.5    sphinxcontrib-qthelp==1.0.7            tensorflow-estimator==2.15.0          toml==0.10.2          uc-micro-py==1.0.3                 xlrd==2.0.1
# anyio==3.7.1                  blinker==1.4            cloudpathlib==0.18.1       cycler==0.12.1         earthengine-api==0.1.409  firebase-admin==5.3.0   geopandas==0.13.2                    google-cloud-firestore==2.11.1            grpcio-status==1.48.2             imageio-ffmpeg==0.5.1       ipython-sql==0.5.0       jupyterlab_widgets==3.0.11            logical-unification==0.4.6  mlxtend==0.22.0          nltk==3.8.1                      pandas==2.0.3                      plotly==5.15.0             psycopg2==2.9.9            pyerfa==2.0.1.4            python-box==7.2.0       rich==13.7.1                six==1.16.0              sphinxcontrib-serializinghtml==1.1.10  tensorflow-gcs-config==2.15.0         tomli==2.0.1          uritemplate==4.1.1                 xyzservices==2024.6.0
# argon2-cffi==23.1.0           blis==0.7.11            cloudpickle==2.2.1         cymem==2.0.8           easydict==1.13            Flask==2.2.5            geopy==2.3.0                         google-cloud-functions==1.13.3            gspread==6.0.2                    imagesize==1.4.1            ipytree==0.2.2           kaggle==1.6.14                        lxml==4.9.4                 more-itertools==10.1.0   notebook==6.5.5                  pandas-datareader==0.10.0          plotnine==0.12.4           ptyprocess==0.7.0          pygame==2.6.0              python-dateutil==2.8.2  rmm-cu12==24.4.0            sklearn-pandas==2.2.0    SQLAlchemy==2.0.31                     tensorflow-hub==0.16.1                toolz==0.12.1         urllib3==2.0.7                     yarl==1.9.4
# argon2-cffi-bindings==21.2.0  blosc2==2.0.0           cmake==3.27.9              Cython==3.0.10         ecos==2.0.14              flatbuffers==24.3.25    gin-config==0.5.0                    google-cloud-iam==2.15.0                  gspread-dataframe==3.3.1          imbalanced-learn==0.10.1    ipywidgets==7.7.1        kagglehub==0.2.5                      malloy==2023.1067           moviepy==1.0.3           notebook_shim==0.2.4             pandas-gbq==0.19.2                 pluggy==1.5.0              py-cpuinfo==9.0.0          Pygments==2.16.1           python-louvain==0.16    rpds-py==0.18.1             smart-open==7.0.4        sqlglot==20.11.0                       tensorflow-io-gcs-filesystem==0.37.0  torchsummary==1.5.1   vega-datasets==0.9.0               yellowbrick==1.5
# array_record==0.5.1           bokeh==3.3.4            cmdstanpy==1.2.4           dask==2023.8.1         editdistance==0.6.2       flax==0.8.4             glob2==0.7                           google-cloud-language==2.13.3             gym==0.25.2                       imgaug==0.4.0               itsdangerous==2.2.0      keras==2.15.0                         marisa-trie==1.2.0          mpmath==1.3.0            numba==0.58.1                    pandas-stubs==2.0.3.230814         polars==0.20.2             py4j==0.10.9.7             PyGObject==3.42.1          python-slugify==8.0.4   rpy2==3.4.2                 sniffio==1.3.1           sqlparse==0.5.0                        tensorflow-metadata==1.15.0           torchtext==0.18.0     wadllib==1.3.6                     yfinance==0.2.40
# arviz==0.15.1                 bqplot==0.12.43         colorcet==3.1.0            datascience==0.17.6    eerepr==0.0.4             folium==0.14.0          google==2.0.3                        google-cloud-pubsub==2.21.5               gym-notices==0.0.8                immutabledict==4.2.0        jax==0.4.26              keyring==23.5.0                       Markdown==3.6               msgpack==1.0.8           numexpr==2.10.1                  pandocfilters==1.5.1               pooch==1.8.2               pyarrow==14.0.2            PyJWT==2.3.0               python-utils==3.8.2     rsa==4.9                    snowballstemmer==2.2.0   srsly==2.4.8                           tensorflow-probability==0.23.0        tornado==6.3.3        wasabi==1.1.3                      zict==3.0.0
# astropy==5.3.4                branca==0.7.2           colorlover==0.3.0          db-dtypes==1.2.0       entrypoints==0.4          fonttools==4.53.0       google-ai-generativelanguage==0.6.4  google-cloud-resource-manager==1.12.3     h5netcdf==1.3.0                   importlib_metadata==8.0.0   jeepney==0.7.1           kiwisolver==1.4.5                     markdown-it-py==3.0.0       multidict==6.0.5         numpy==1.25.2                    panel==1.3.8                       portpicker==1.5.2          pyarrow-hotfix==0.6        pymc==5.10.4               pytz==2023.4            safetensors==0.4.3          sortedcontainers==2.4.0  stanio==0.5.0                          tensorstore==0.1.45                   tqdm==4.66.4          wcwidth==0.2.13                    zipp==3.19.2
# astunparse==1.6.3             build==1.2.1            colour==0.1.5              dbus-python==1.2.18    et-xmlfile==1.1.0         frozendict==2.4.4       google-api-core==2.16.2              google-cloud-storage==2.8.0               h5py==3.9.0                       importlib_resources==6.4.0  jellyfish==1.0.4         langcodes==3.4.0                      MarkupSafe==2.1.5           multipledispatch==1.0.0  nvtx==0.2.10                     param==2.1.1                       prefetch-generator==1.0.3  pyasn1==0.6.0              pymystem3==0.2.0           pyviz_comms==3.0.2      scikit-image==0.19.3        soundfile==0.12.1        statsmodels==0.14.2                    termcolor==2.4.0                      traitlets==5.7.1      weasel==0.4.1
# async-timeout==4.0.3          CacheControl==0.14.0    community==1.0.0b1         debugpy==1.6.6         etils==1.7.0              frozenlist==1.4.1       google-api-python-client==2.84.0     google-cloud-translate==3.11.3            holidays==0.52                    imutils==0.5.4              jieba==0.42.1            language_data==1.2.0                  matplotlib==3.7.1           multitasking==0.0.11     oauth2client==4.1.3              parso==0.8.4                       preshed==3.0.9             pyasn1_modules==0.4.0      pynvjitlink-cu12==0.2.4    PyWavelets==1.6.0       scikit-learn==1.2.2         soupsieve==2.5           StrEnum==0.4.15                        terminado==0.18.1                     traittypes==0.2.1     webcolors==24.6.0
# atpublic==4.1.0               cachetools==5.3.3       confection==0.1.5          decorator==4.4.2       etuples==0.3.9            fsspec==2023.6.0        google-auth==2.27.0                  google-crc32c==1.5.0                      holoviews==1.17.1                 inflect==7.0.0              Jinja2==3.1.4            launchpadlib==1.10.16                 matplotlib-inline==0.1.7    murmurhash==1.0.10       oauthlib==3.2.2                  parsy==2.1                         prettytable==3.10.0        pycocotools==2.0.8         PyOpenGL==3.1.7            PyYAML==6.0.1           scipy==1.11.4               soxr==0.3.7              sympy==1.12.1                          text-unidecode==1.3                   transformers==4.41.2  webencodings==0.5.1
# attrs==23.2.0                 catalogue==2.0.10       cons==0.4.6                defusedxml==0.7.1      exceptiongroup==1.2.1     future==0.18.3          google-auth-httplib2==0.1.1          google-generativeai==0.5.4                html5lib==1.1                     iniconfig==2.0.0            joblib==1.4.2            lazr.restfulclient==0.14.4            matplotlib-venn==0.11.10    music21==9.1.0           opencv-contrib-python==4.8.0.76  partd==1.4.2                       proglog==0.1.10            pycparser==2.22            pyOpenSSL==24.1.0          pyzmq==24.0.1           scooby==0.10.0              spacy==3.7.5             tables==3.8.0                          textblob==0.17.1                      triton==2.3.0         websocket-client==1.8.0
# audioread==3.0.1              certifi==2024.6.2       contextlib2==21.6.0        distributed==2023.8.1  fastai==2.7.15            gast==0.6.0             google-auth-oauthlib==1.2.0          google-pasta==0.2.0                       httpimport==1.3.1                 intel-openmp==2023.2.4      jsonpickle==3.2.2        lazr.uri==1.0.6                       mdit-py-plugins==0.4.1      natsort==8.4.0           opencv-python==4.8.0.76          pathlib==1.0.1                     progressbar2==4.2.0        pydantic==2.8.0            pyparsing==3.1.2           qdldl==0.1.7.post4      scs==3.2.5                  spacy-legacy==3.0.12     tabulate==0.9.0                        tf-slim==1.1.0                        tweepy==4.14.0        Werkzeug==3.0.3
# cudf-cu12 @ https://pypi.nvidia.com/cudf-cu12/cudf_cu12-24.4.1-cp310-cp310-manylinux_2_28_x86_64.whl#sha256=57366e7ef09dc63e0b389aff20df6c37d91e2790065861ee31a4720149f5b694
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl#sha256=86cc141f63942d4b2c5fcee06630fd6f904788d2f0ab005cce45aadb8fb73889
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz#sha256=9db45b02b9257690150b949c5becb6d56fa09d50ea41a2f189705915d83d86fa
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda12/jaxlib-0.4.26+cuda12.cudnn89-cp310-cp310-manylinux2014_x86_64.whl#sha256=813cf1fe3e7ca4dbf5327d6e7b4fc8521e92d8bba073ee645ae0d5d036a25750
# python-apt @ file:///backend-container/containers/python_apt-0.0.0-cp310-cp310-linux_x86_64.whl#sha256=b209c7165d6061963abe611492f8c91c3bcef4b7a6600f966bab58900c63fefa
# tensorflow @ https://storage.googleapis.com/colab-tf-builds-public-09h6ksrfwbb9g9xv/tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=a2ec79931350b378c1ef300ca836b52a55751acb71a433582508a07f0de57c42
# torch @ https://download.pytorch.org/whl/cu121/torch-2.3.0%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=0a12aa9aa6bc442dff8823ac8b48d991fd0771562eaa38593f9c8196d65f7007
# torchaudio @ https://download.pytorch.org/whl/cu121/torchaudio-2.3.0%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=38b49393f8c322dcaa29d19e5acbf5a0b1978cf1b719445ab670f1fb486e3aa6
# torchvision @ https://download.pytorch.org/whl/cu121/torchvision-0.18.0%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=13e1b48dc5ce41ccb8100ab3dd26fdf31d8f1e904ecf2865ac524493013d0df5

# %%
colab_ip = %system hostname -I   # uses colab magic to get list from bash
colab_ip = colab_ip[0].strip()   # returns "172.28.0.12"
colab_port = 9000                # could use 6000, 8080, or 9000

notebook_filename = filename = requests.get(f"http://{colab_ip}:{colab_port}/api/sessions").json()[0]["name"]

# Avoids scroll-in-the-scroll in the entire Notebook
def resize_colab_cell():
  display(IPython.display.Javascript('google.colab.output.setIframeHeight(0, true, {maxHeight: 10000})'))
get_ipython().events.register('pre_run_cell', resize_colab_cell)


#@markdown ### func `def get_path_to_save(...):`
def get_path_to_save(plot_props:dict=None, file_prefix="", save_filename:str=None, save_in_subfolder:str=None, extension="jpg", dot=".", create_folder_if_necessary=True):
    """
    Code created myself (Rahul Yerrabelli)
    """
    replace_characters = {
        "$": "",
        "\\frac":"",
        "\\mathrm":"",
        "\\left(":"(",
        "\\right)":")",
        "\\left[":"[",
        "\\right]":"]",
        "\\": "",
        "/":"-",
        "{": "(",
        "}": ")",
        "<":"",
        ">":"",
        "?":"",
        "_":"",
        "^":"",
        "*":"",
        "!":"",
        ":":"-",
        "|":"-",
        ".":"_",
    }

    # define save_filename based on plot_props
    if save_filename is None:
        save_filename = "unnamed"

    #save_path = f"../outputs/{notebook_filename.split('.',1)[0]}"
    save_path = [
                 "outputs",
                f"{notebook_filename.split('.',1)[0]}",
                ]
    if save_in_subfolder is not None:
        if isinstance(save_in_subfolder, (list, tuple, set, np.ndarray) ):
            save_path.append(**save_in_subfolder)
        else:  # should be a string then
            save_path.append(save_in_subfolder)
    save_path = os.path.join(*save_path)

    if not os.path.exists(save_path) and create_folder_if_necessary:
        os.makedirs(save_path)
    return os.path.join(save_path, file_prefix+save_filename+dot+extension)
    #plt.savefig(os.path.join(save_path, save_filename+dot+extension))

# %%
#@title ## Mount google drive and import my code

mountpoint_folder_name = "drive"  # can be anything, doesn't have to be "drive"
project_path_within_drive = "PythonProjects/ECV-Analysis" #@param {type:"string"}
#project_path_within_drive = "UIUC ECs/Rahul_Ashkhan_Projects/SpeculumProjects_Shared/Analysis" #@param {type:"string"}
project_path_full = os.path.join("/content/",mountpoint_folder_name,
                        "MyDrive",project_path_within_drive)

# %cd {project_path_full}
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/PythonProjects/ECV-Analysis'
# /content

# %%
try:
    import google.colab.drive
    import os, sys
    # Need to move out of google drive directory if going to remount
    # %cd
    # drive.mount documentation can be accessed via: drive.mount?
    #Signature: drive.mount(mountpoint, force_remount=False, timeout_ms=120000, use_metadata_server=False)
    google.colab.drive.mount(os.path.join("/content/",mountpoint_folder_name), force_remount=True)  # mounts to a folder called mountpoint_folder_name

    if project_path_full not in sys.path:
        pass
        #sys.path.insert(0,project_path_full)
    # %cd {project_path_full}

except ModuleNotFoundError:  # in case not run in Google colab
    import traceback
    traceback.print_exc()
# Out:
# /root
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1okL5s1HTQUWqKodPSVNP_RsK0o81IH5E/PythonProjects2/ECV-Analysis

# %%
def convert_wga_to_total_days(ga, return_separately=False):  # convert "37w 3d" to 262
    """
    "20w 2d" -> 142
    "20w2d" -> 142
    "20w" -> 140
    "5w" -> 35
    """
    if isinstance(ga, str):
        assert "w" in ga
        wks_str, days_str = ga.split("w",maxsplit=1)
        wks = int(wks_str)
        days_str = days_str.strip()
        if days_str.endswith("d"):
            days_str = days_str[:-1]
        if days_str == "":
            days = 0
        else:
            days = int(days_str)

        if return_separately:
            return (wks,days)
        else:
            return wks*7+days
    else:
        return None

def convert_total_days_to_wga(total_days):
    days = total_days % 7
    wks = round((total_days - days)/7)   # shouldn't need to round, but used to convert float to int
    wga = f"{wks:g}w{days}d"
    return wga

# %% [markdown]
# ## Calculating EFW at a specific time using prior ultrasound
#
# How to use coefficients
# $\ln(EFW)= b_0 + b_1 \cdot t +b_2 \cdot t^2 +b_3 \cdot t^3 +b_4 \cdot t^4$ where $t$ is GA in weeks.
# For percentiles not described, you can use interpolation. For example, take a percentile $\alpha$ surrounded by two defined percentiles ie $\alpha_0<\alpha<\alpha_1$. Then:
# $\ln(EFW_\alpha)=\frac{\ln(EFW_{\alpha_1})-\ln(EFW_{\alpha_0})}{\alpha_1-\alpha_0} \cdot (\alpha-\alpha_0) + \ln(EFW_{\alpha_0})$

# %%
def calculate_efw(ga_wks, sex, quantile):
    from numpy.polynomial import Polynomial
    from numpy.polynomial.polynomial import polyval

    # sex input can already be "M" and "F" or can be 1 vs 2 (this numeric system matches the other spreadsheet)
    if sex==1:
        sex="F"
    elif sex==2:
        sex="M"
    if ga_wks is None or sex is None or quantile is None or np.isnan(ga_wks) or np.isnan(quantile):  # will throw error if check if sex (str) is np.isnan
        return np.nan
    if ga_wks < 14 or ga_wks > 50:
        raise ValueError("ga_wks appears to be in days instead of weeks")
    unique_quantiles = efw_who_coeffs_df.index.levels[1]
    if quantile in unique_quantiles:
        #b0,b1,b2,b3,b4 = efw_who_coeffs_df.loc[(sex,quantile)]
        #ln_b0 + b1*t + b2*t**2 +b3*t**3 +b4*t**4
        ln_efw = np.polynomial.polynomial.polyval(ga_wks, efw_who_coeffs_df.loc[(sex,quantile)])
        efw =np.exp(ln_efw)
        return efw
    elif quantile < np.min(unique_quantiles) or quantile > np.max(unique_quantiles):
        return np.nan   # do not extrapolate if too extreme eg <0.001%
    else:
        closest_quantile_lower = unique_quantiles[unique_quantiles <= quantile].max()
        closest_quantile_upper = unique_quantiles[unique_quantiles > quantile].min()
        try:
            ln_efw_lower = np.polynomial.polynomial.polyval(ga_wks, efw_who_coeffs_df.loc[(sex,closest_quantile_lower)])
        except KeyError:
            print(f"KeyError for {(sex,closest_quantile_lower)}. (ga_wks, sex, quantile) = ({ga_wks}, {sex}, {quantile}).")
            return np.nan
        try:
            ln_efw_upper = np.polynomial.polynomial.polyval(ga_wks, efw_who_coeffs_df.loc[(sex,closest_quantile_upper)])
        except KeyError:
            print(f"KeyError for {(sex,closest_quantile_lower)}. (ga_wks, sex, quantile) = ({ga_wks}, {sex}, {quantile})")
            return np.nan
        ln_efw = (ln_efw_upper-ln_efw_lower)/(closest_quantile_upper-closest_quantile_lower) * (quantile-closest_quantile_lower) + ln_efw_lower
        efw= np.exp(ln_efw)
        return efw

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Get raw data

# %%
computerized_records_df = pd.read_csv("data/01_raw/Computerized_data_2024-03-13_1752.csv", index_col=0,
                                      converters={
                                          #"ecv_successful_1":bool  # has to be float (default) to allow NaN
                                      })
manual_records_df = pd.read_excel("data/01_raw/Manual_USData_v14.xlsx", index_col=0,
                                  converters={
                                      "Skip":str,
                                      "ECV to Delivery (days)":int,  # some are floats like 10.6, will get rounded down
                                      "Delivery GA": convert_wga_to_total_days,
                                      })
# Below file can also be found online at
## https://github.com/jcarvalho45/whoFetalGrowth/blob/main/coefficientsEFWbySexV3.csv
## https://srhr.org/fetalgrowthcalculator/#/
## Kiserud 2017. The World Health Organization Fetal Growth Charts: A Multinational Longitudinal Study of Ultrasound Biometric Measurements and Estimated Fetal Weight. https://doi.org/10.1371/journal.pmed.1002220
## Kiserud 2018. The World Health Organization fetal growth charts: concept, findings, interpretation, and application. https://doi.org/10.1016/j.ajog.2017.12.010

efw_who_coeffs_df = pd.read_csv("data/01_raw/WHOcoefficientsEFWbySexV3.csv", index_col=[0,1])

manual_records_df
# Out:
#            Skip ECV Done? Presentation Pre-ECV   Presentation US  \
# subject_id
# 1            No       Yes                  NaN     Breech, frank
# 2            No       Yes                  NaN            Breech
# 3            No       Yes                  NaN        Transverse
# 4           Yes       Yes                  NaN               NaN
# 5            No       Yes                  NaN  Breech, footling
# ...         ...       ...                  ...               ...
# 161         Yes       NaN                  NaN               NaN
# 162          No       Yes                  NaN     Breech, frank
# 163         Yes        No                  NaN               NaN
# 164         Yes        No                  NaN               NaN
# 165          No       Yes                  NaN            Breech
#
#                  Placenta Location Placenta Grade    AFI          SDP  \
# subject_id
# 1           posterior left lateral      Grade 1-2  14.46          NaN
# 2                   posterior high      Grade 1-2  10.76  3.33 x 3.05
# 3                         anterior        Grade 2  20.90          NaN
# 4                              NaN            NaN    NaN          NaN
# 5                   anterior right        Grade 1  12.17  5.84 x 3.01
# ...                            ...            ...    ...          ...
# 161                            NaN            NaN    NaN          NaN
# 162                  posterior mid        Grade 2  10.70          NaN
# 163                            NaN            NaN    NaN          NaN
# 164                            NaN            NaN    NaN          NaN
# 165                 posterior high      Grade 1-2  26.26          NaN
#
#                     Fetal Spine  US EFW (g)  US EFW (%)  \
# subject_id
# 1                           NaN      2563.0        0.36
# 2                           NaN      2877.0        0.68
# 3                           NaN      2877.0        0.68
# 4                           NaN         NaN         NaN
# 5           Spine to maternal R      3335.0        0.71
# ...                         ...         ...         ...
# 161                         NaN         NaN         NaN
# 162                         NaN      2601.0        0.12
# 163                         NaN         NaN         NaN
# 164                         NaN         NaN         NaN
# 165                         NaN      2851.0        0.55
#
#            ECV to Delivery (days)  Delivery GA Delivery Type Brief  \
# subject_id
# 1                               0          262           C-Section
# 2                              14          274             Vaginal
# 3                              24          283             Vaginal
# 4                               7          282           C-Section
# 5                              14          275           C-Section
# ...                           ...          ...                 ...
# 161                           NaN          273           C-Section
# 162                            10          274           C-Section
# 163                           NaN          275           C-Section
# 164                           NaN          257           C-Section
# 165                             1          261             Vaginal
#
#            Delivery Type Detail Delivery Type Ct  \
# subject_id
# 1                Low Transverse          Primary
# 2                   Spontaneous              NaN
# 3                   Spontaneous              NaN
# 4                Low Transverse          Primary
# 5                Low Transverse          Primary
# ...                         ...              ...
# 161              Low Transverse          Primary
# 162              Low Transverse          Primary
# 163              Low Transverse          Primary
# 164              Low Transverse              NaN
# 165                 Spontaneous              NaN
#
#                                          Notes
# subject_id
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4           US report was 6 months before ECV
# 5                                          NaN
# ...                                        ...
# 161                            No US available
# 162                                        NaN
# 163                                        NaN
# 164                                        NaN
# 165                                        NaN
#
# [165 rows x 17 columns]

# %% [markdown]
# ## Combine raw data and process it

# %%
all_records_by_pt_df=pd.merge(left=manual_records_df, right=computerized_records_df, on="subject_id")
# Filter out columns marked to be skipped (eg ECV wasn't actually done)
all_records_by_pt_df = all_records_by_pt_df[all_records_by_pt_df["Skip"]!="Yes"]

# These five columns were empty for every pt, so will just remove them
all_records_by_pt_df = all_records_by_pt_df.drop(columns=["marijuana_use","cocaine_use","amphetamines_use","opiates_use","substance_use_complete"])
# "Skip" and "include_pregnancy" mean the same, so can remove one of them
all_records_by_pt_df = all_records_by_pt_df.drop(columns=["include_pregnancy"])


# The computer only counted up to 3 ECVs in a patient. However, one patient (Pt #45) had four ECVs. The fourth one was a failure (unlike the first 3). Here I add another pair of columns for the 4th ECV and mark it as a ECV failure
all_records_by_pt_df.insert(all_records_by_pt_df.columns.get_loc("ecv_successful_3")+2, "ecv_successful_4", np.nan)
all_records_by_pt_df.insert(all_records_by_pt_df.columns.get_loc("ecv_fetal_abnormal_3")+2, "ecv_fetal_abnormal_4", np.nan)
all_records_by_pt_df.loc[45, "ecv_successful_4"] = 0

# For pt 102, after initial ECV, turned back within 2 min, and second ECV was done successfully. Few hours later, midwife noticed return to breech, and third ECV was done. No further turns or ECVs were documented. Vaginal delivery went smoothly.
# Computer records only counted the first ECV. Will add the remaining ECVs as successful
all_records_by_pt_df.loc[102, "ecv_successful_2"] = 1
all_records_by_pt_df.loc[102, "ecv_successful_3"] = 1


# Do same basic processing
proc_records_by_pt_df = all_records_by_pt_df.copy()

# For some patients, we have the presentation immediately before the ECV. Others, we only have the presentation on the last US. These are both in separate columns. We will combine them into one called "Presentation US"
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("Presentation Pre-ECV"), "Presentation", proc_records_by_pt_df["Presentation Pre-ECV"])
proc_records_by_pt_df["Presentation"].fillna(proc_records_by_pt_df["Presentation US"], inplace=True)
# The presentation description will be specific eg "Breech, complete; vertex on maternal L". We will drop the specifics by splitting at the ";"
proc_records_by_pt_df["Presentation"] = proc_records_by_pt_df["Presentation"].str.split(pat = ";", expand=True)[0]
# We will no split up the brief and detail presentation info (eg "Breech" and "complete") into separate columns
#proc_records_by_pt_df[["Presentation Brief", "Presentation Detail"]] = proc_records_by_pt_df["Presentation"].str.split(pat = ",", expand=True)
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("Presentation"), "Presentation Brief", proc_records_by_pt_df["Presentation"].str.split(pat = ",", expand=True)[0].str.strip())
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("Presentation"), "Presentation Detail", proc_records_by_pt_df["Presentation"].str.split(pat = ",", expand=True)[1].str.strip())
proc_records_by_pt_df = proc_records_by_pt_df.drop(columns=["Presentation","Presentation Pre-ECV","Presentation US"])

# Use available information to calculate GA at ECV
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("ECV to Delivery (days)"), "ECV GA", proc_records_by_pt_df["Delivery GA"]-proc_records_by_pt_df["ECV to Delivery (days)"])
# Use the EFW % from the last US to calculat the EFW at the time of ECV and delivery
# There are 5 data points that an "US EFW (g)" recorded, but not an "US EFW (%)". Ignore these as these are from old ultrasounds anyway (when EFW <1000g)
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("US EFW (%)")+1, "ECV EFW (g)",
                             proc_records_by_pt_df.apply(lambda row: calculate_efw(row["ECV GA"]/7, row["baby_gender_1"], row["US EFW (%)"]), axis=1))
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("US EFW (%)")+2, "Delivery EFW (g)",
                             proc_records_by_pt_df.apply(lambda row: calculate_efw(row["Delivery GA"]/7, row["baby_gender_1"], row["US EFW (%)"]), axis=1))
# Alternatively, do it by iterating through df
#for index, row in proc_records_by_pt_df.iterrows():
#    (calculate_efw(row["ECV GA"]/7, row["baby_gender_1"], row["US EFW (%)"]))

# Some rows do not have an AFI. Estimate it from SDP
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("AFI"), "AFI equiv", proc_records_by_pt_df["AFI"])
# Most values of SDP are in format like "3.97 x 2.75", although some are just "3.97". Split will return na if the pattern "x" is not found
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("SDP"), "SDP1", proc_records_by_pt_df["SDP"].str.split(pat="x", n=1, expand=True)[0].str.strip())
proc_records_by_pt_df["SDP1"].fillna(proc_records_by_pt_df["SDP"], inplace=True)
def SDP_to_AFI(sdp):
    return sdp * 3
proc_records_by_pt_df["AFI equiv"].fillna(SDP_to_AFI(pd.to_numeric(proc_records_by_pt_df["SDP1"])), inplace=True)
proc_records_by_pt_df.drop(columns=["SDP"])

# Some rows do not have a delivery BMI, only initial. Fortunately, all but pt 3 have an initial BMI (pt 3 has no BMIs or weights)
# Create a "last bmi" column. If no other BMI is available, this will be the first BMI.
proc_records_by_pt_df.insert(proc_records_by_pt_df.columns.get_loc("delivery_bmi"), "last_bmi", proc_records_by_pt_df["delivery_bmi"])
proc_records_by_pt_df["last_bmi"].fillna(proc_records_by_pt_df["first_bmi"], inplace=True)

# number of ECVs done/attempted
proc_records_by_pt_df["ecv_tries"] = proc_records_by_pt_df[["ecv_successful_1","ecv_successful_2","ecv_successful_3","ecv_successful_4"]].notna().sum(axis=1)

# %% [markdown]
# ## Get df with data by ECV attempt

# %%
ecv_num_options = "1234"

# make a dataframe where each row is an ECV, not just a patient
proc_records_by_ecv_df = pd.melt(proc_records_by_pt_df.reset_index(),  # need to reset index so that subject_id can be access
                                 id_vars=["subject_id"],
                                 value_vars=[f"ecv_successful_{ecv_num}" for ecv_num in ecv_num_options],
                                 var_name="ecv_num", value_name="ecv_successful"
                                 ).dropna(subset="ecv_successful")

# convert ecv_num values from "ecv_successful_x" to "ecv_successful_x" where x is in {1,2,3,4}
proc_records_by_ecv_df["ecv_num"] = proc_records_by_ecv_df["ecv_num"].str.split(pat = "_", expand=True)[2].str.strip().astype(int)
# Get all the other values from the original dataframe from the subject_id
proc_records_by_ecv_df = pd.merge(proc_records_by_ecv_df, proc_records_by_pt_df.reset_index(), on = "subject_id")
# Drop values that are specific to the ecv (except for ecv_num)
proc_records_by_ecv_df = proc_records_by_ecv_df.drop(columns = [col for col in proc_records_by_ecv_df.columns if col.lower().startswith("ecv_") and col.split("_")[-1] in ecv_num_options])
# Put back subject_id into the index as well as ecv_num
proc_records_by_ecv_df = proc_records_by_ecv_df.set_index(["subject_id","ecv_num"]).sort_index()

# %% [markdown]
# ## Exportable ECV file

# %%
proc_records_by_pt_df.head()
# Out:
#            Skip ECV Done? Presentation Brief Presentation Detail  \
# subject_id
# 1            No       Yes             Breech               frank
# 2            No       Yes             Breech                None
# 3            No       Yes         Transverse                None
# 5            No       Yes             Breech            footling
# 6            No       Yes             Breech               frank
#
#                  Placenta Location Placenta Grade  AFI equiv    AFI  SDP1  \
# subject_id
# 1           posterior left lateral      Grade 1-2      14.46  14.46   NaN
# 2                   posterior high      Grade 1-2      10.76  10.76  3.33
# 3                         anterior        Grade 2      20.90  20.90   NaN
# 5                   anterior right        Grade 1      12.17  12.17  5.84
# 6                   posterior high        Grade 1       6.71   6.71  2.69
#
#                     SDP          Fetal Spine  US EFW (g)  US EFW (%)  \
# subject_id
# 1                   NaN                  NaN      2563.0        0.36
# 2           3.33 x 3.05                  NaN      2877.0        0.68
# 3                   NaN                  NaN      2877.0        0.68
# 5           5.84 x 3.01  Spine to maternal R      3335.0        0.71
# 6           2.69 x 2.37                  NaN      2736.0        0.29
#
#             ECV EFW (g)  Delivery EFW (g) ECV GA ECV to Delivery (days)  \
# subject_id
# 1           2963.197413       2963.197413    262                      0
# 2           3106.886213       3565.104487    260                     14
# 3           3170.023699       3931.746889    259                     24
# 5           3265.582284       3719.951169    261                     14
# 6           3336.493981       3365.044654    277                      1
#
#             Delivery GA Delivery Type Brief Delivery Type Detail  \
# subject_id
# 1                   262           C-Section       Low Transverse
# 2                   274             Vaginal          Spontaneous
# 3                   283             Vaginal          Spontaneous
# 5                   275           C-Section       Low Transverse
# 6                   278             Vaginal          Spontaneous
#
#            Delivery Type Ct Notes  age_delivery  first_bmi  first_weight  \
# subject_id
# 1                   Primary   NaN            33      21.49    118.000000
# 2                       NaN   NaN            36      27.37    180.000000
# 3                       NaN   NaN            29        NaN           NaN
# 5                   Primary   NaN            35      27.57    174.000000
# 6                       NaN   NaN            36      18.18    102.624375
#
#             last_bmi  delivery_bmi  delivery_weight        twg  ethnicity  \
# subject_id
# 1              21.49           NaN            143.0  25.000000         12
# 2              27.37           NaN            200.0  20.000000         12
# 3                NaN           NaN              NaN        NaN         12
# 5              30.34         30.34            188.0  14.000000         12
# 6              23.91         23.91            135.0  32.375625         12
#
#             patient_race___1  patient_race___2  patient_race___3  \
# subject_id
# 1                          1                 0                 0
# 2                          1                 0                 0
# 3                          1                 0                 0
# 5                          1                 0                 0
# 6                          1                 0                 0
#
#             patient_race___4  patient_race___5  patient_race___6  \
# subject_id
# 1                          0                 0                 0
# 2                          0                 0                 0
# 3                          0                 0                 0
# 5                          0                 0                 0
# 6                          0                 0                 0
#
#             patient_race___7  patient_race___8  patient_race___9  language_c  \
# subject_id
# 1                          0                 0                 0           1
# 2                          0                 0                 0           1
# 3                          0                 0                 0           1
# 5                          0                 0                 0           1
# 6                          0                 0                 0           1
#
#             interpreter_needed_yn  baby_gender_1  baby_status_1  \
# subject_id
# 1                             0.0              2              1
# 2                             0.0              1              1
# 3                             NaN              2              1
# 5                             0.0              2              1
# 6                             0.0              2              1
#
#             baby_gender_2  baby_status_2  gravida_this_pregnancy  \
# subject_id
# 1                     NaN            NaN                       1
# 2                     NaN            NaN                       4
# 3                     NaN            NaN                       3
# 5                     NaN            NaN                       3
# 6                     NaN            NaN                       3
#
#             para_this_pregnancy  term_this_pregnancy  preterm_this_pregnancy  \
# subject_id
# 1                             0                    0                       0
# 2                             3                    3                       0
# 3                             2                    2                       0
# 5                             2                    2                       0
# 6                             2                    2                       0
#
#             rupture_membranes  gravida_prev_preg_1  gravida_prev_preg_2  \
# subject_id
# 1                         1.0                  NaN                  NaN
# 2                         3.0                  3.0                  NaN
# 3                         5.0                  NaN                  NaN
# 5                         3.0                  1.0                  2.0
# 6                         1.0                  1.0                  2.0
#
#             gravida_prev_preg_3  gravida_prev_preg_4  gravida_prev_preg_5  \
# subject_id
# 1                           NaN                  NaN                  NaN
# 2                           NaN                  NaN                  NaN
# 3                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
# 6                           NaN                  NaN                  NaN
#
#             para_prev_preg_1  para_prev_preg_2  para_prev_preg_3  \
# subject_id
# 1                        NaN               NaN               NaN
# 2                        2.0               NaN               NaN
# 3                        NaN               NaN               NaN
# 5                        0.0               1.0               NaN
# 6                        0.0               1.0               NaN
#
#             para_prev_preg_4  para_prev_preg_5  term_prev_preg_1  \
# subject_id
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               2.0
# 3                        NaN               NaN               NaN
# 5                        NaN               NaN               0.0
# 6                        NaN               NaN               0.0
#
#             term_prev_preg_2  term_prev_preg_3  term_prev_preg_4  \
# subject_id
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               NaN
# 3                        NaN               NaN               NaN
# 5                        1.0               NaN               NaN
# 6                        1.0               NaN               NaN
#
#             term_prev_preg_5  preterm_prev_preg_1  preterm_prev_preg_2  \
# subject_id
# 1                        NaN                  NaN                  NaN
# 2                        NaN                  0.0                  NaN
# 3                        NaN                  NaN                  NaN
# 5                        NaN                  0.0                  0.0
# 6                        NaN                  0.0                  0.0
#
#             preterm_prev_preg_3  preterm_prev_preg_4  preterm_prev_preg_5  \
# subject_id
# 1                           NaN                  NaN                  NaN
# 2                           NaN                  NaN                  NaN
# 3                           NaN                  NaN                  NaN
# 5                           NaN                  NaN                  NaN
# 6                           NaN                  NaN                  NaN
#
#             chronic_htn_before  chronic_htn_during  dm1_before  dm1_during  \
# subject_id
# 1                          NaN                 NaN         NaN         NaN
# 2                          NaN                 NaN         NaN         NaN
# 3                          NaN                 NaN         NaN         NaN
# 5                          NaN                 NaN         NaN         NaN
# 6                          NaN                 NaN         NaN         NaN
#
#             dm2_before  dm2_during  gestational_dm_during  \
# subject_id
# 1                  NaN         NaN                    NaN
# 2                  NaN         NaN                    NaN
# 3                  NaN         NaN                    NaN
# 5                  NaN         NaN                    NaN
# 6                  NaN         NaN                    NaN
#
#             preeclampsia_during  pregnancy_episode_delivery_complete  \
# subject_id
# 1                           NaN                                    2
# 2                           NaN                                    2
# 3                           NaN                                    2
# 5                           NaN                                    2
# 6                           NaN                                    2
#
#             ecv_successful_1  ecv_fetal_abnormal_1  ecv_successful_2  \
# subject_id
# 1                        1.0                   NaN               NaN
# 2                        1.0                   NaN               NaN
# 3                        0.0                   NaN               NaN
# 5                        0.0                   NaN               NaN
# 6                        1.0                   NaN               NaN
#
#             ecv_fetal_abnormal_2  ecv_successful_3  ecv_fetal_abnormal_3  \
# subject_id
# 1                            NaN               NaN                   NaN
# 2                            NaN               NaN                   NaN
# 3                            NaN               NaN                   NaN
# 5                            NaN               NaN                   NaN
# 6                            NaN               NaN                   NaN
#
#             ecv_successful_4  ecv_fetal_abnormal_4  ecv_complete  \
# subject_id
# 1                        NaN                   NaN             2
# 2                        NaN                   NaN             2
# 3                        NaN                   NaN             2
# 5                        NaN                   NaN             2
# 6                        NaN                   NaN             2
#
#             ultrasounds_complete  tobacco_use  alcohol_use  ill_drug_use  \
# subject_id
# 1                              0          2.0          2.0           2.0
# 2                              2          NaN          NaN           NaN
# 3                              2          NaN          NaN           NaN
# 5                              2          NaN          NaN           NaN
# 6                              2          NaN          NaN           NaN
#
#             ecv_tries
# subject_id
# 1                   1
# 2                   1
# 3                   1
# 5                   1
# 6                   1

# %%
# Number of unique values, number of non-null values, and total size
col_cts=proc_records_by_pt_df.agg(["nunique","count","size"])
with pd.option_context("display.max_columns", None):
    display(col_cts)
# Out:
#          Skip  ECV Done?  Presentation Brief  Presentation Detail  \
# nunique     1          1                   3                   11
# count     125        125                 125                   57
# size      125        125                 125                  125
#
#          Placenta Location  Placenta Grade  AFI equiv  AFI  SDP1  SDP  \
# nunique                 17               6        121  117    11   11
# count                  125             125        125  120    11   11
# size                   125             125        125  125   125  125
#
#          Fetal Spine  US EFW (g)  US EFW (%)  ECV EFW (g)  Delivery EFW (g)  \
# nunique            8         114          58          109               110
# count             21         117         112          112               112
# size             125         125         125          125               125
#
#          ECV GA  ECV to Delivery (days)  Delivery GA  Delivery Type Brief  \
# nunique      28                      25           28                    2
# count       125                     125          125                  125
# size        125                     125          125                  125
#
#          Delivery Type Detail  Delivery Type Ct  Notes  age_delivery  \
# nunique                     3                 3     15            23
# count                     125                71     15           125
# size                      125               125    125           125
#
#          first_bmi  first_weight  last_bmi  delivery_bmi  delivery_weight  \
# nunique        121           109       117            89               84
# count          124           124       124            95              124
# size           125           125       125           125              125
#
#          twg  ethnicity  patient_race___1  patient_race___2  patient_race___3  \
# nunique   98          3                 2                 2                 2
# count    124        125               125               125               125
# size     125        125               125               125               125
#
#          patient_race___4  patient_race___5  patient_race___6  \
# nunique                 2                 2                 2
# count                 125               125               125
# size                  125               125               125
#
#          patient_race___7  patient_race___8  patient_race___9  language_c  \
# nunique                 1                 2                 1           5
# count                 125               125               125         125
# size                  125               125               125         125
#
#          interpreter_needed_yn  baby_gender_1  baby_status_1  baby_gender_2  \
# nunique                      2              2              1              0
# count                      119            125            125              0
# size                       125            125            125            125
#
#          baby_status_2  gravida_this_pregnancy  para_this_pregnancy  \
# nunique              0                       9                    6
# count                0                     125                  125
# size               125                     125                  125
#
#          term_this_pregnancy  preterm_this_pregnancy  rupture_membranes  \
# nunique                    5                       3                  4
# count                    125                     125                 95
# size                     125                     125                125
#
#          gravida_prev_preg_1  gravida_prev_preg_2  gravida_prev_preg_3  \
# nunique                    5                    4                    4
# count                     51                   20                   10
# size                     125                  125                  125
#
#          gravida_prev_preg_4  gravida_prev_preg_5  para_prev_preg_1  \
# nunique                    2                    1                 3
# count                      4                    1                51
# size                     125                  125               125
#
#          para_prev_preg_2  para_prev_preg_3  para_prev_preg_4  \
# nunique                 4                 4                 3
# count                  20                10                 4
# size                  125               125               125
#
#          para_prev_preg_5  term_prev_preg_1  term_prev_preg_2  \
# nunique                 1                 3                 4
# count                   1                51                20
# size                  125               125               125
#
#          term_prev_preg_3  term_prev_preg_4  term_prev_preg_5  \
# nunique                 4                 3                 1
# count                  10                 4                 1
# size                  125               125               125
#
#          preterm_prev_preg_1  preterm_prev_preg_2  preterm_prev_preg_3  \
# nunique                    2                    2                    2
# count                     51                   20                   10
# size                     125                  125                  125
#
#          preterm_prev_preg_4  preterm_prev_preg_5  chronic_htn_before  \
# nunique                    1                    1                   2
# count                      4                    1                  14
# size                     125                  125                 125
#
#          chronic_htn_during  dm1_before  dm1_during  dm2_before  dm2_during  \
# nunique                   2           2           2           2           2
# count                    14          10          12          10          13
# size                    125         125         125         125         125
#
#          gestational_dm_during  preeclampsia_during  \
# nunique                      2                    2
# count                       14                   14
# size                       125                  125
#
#          pregnancy_episode_delivery_complete  ecv_successful_1  \
# nunique                                    1                 2
# count                                    125               125
# size                                     125               125
#
#          ecv_fetal_abnormal_1  ecv_successful_2  ecv_fetal_abnormal_2  \
# nunique                     2                 2                     1
# count                      28                 4                     1
# size                      125               125                   125
#
#          ecv_successful_3  ecv_fetal_abnormal_3  ecv_successful_4  \
# nunique                 1                     0                 1
# count                   2                     0                 1
# size                  125                   125               125
#
#          ecv_fetal_abnormal_4  ecv_complete  ultrasounds_complete  \
# nunique                     0             1                     3
# count                       0           125                   125
# size                      125           125                   125
#
#          tobacco_use  alcohol_use  ill_drug_use  ecv_tries
# nunique            3            4             2          4
# count             27           26            27        125
# size             125          125           125        125

# %%
unique_value_ct_by_col=all_records_by_pt_df.nunique()
cols_without_unique_values = unique_value_ct_by_col[unique_value_ct_by_col<=1]
display(cols_without_unique_values)
# Out:
# Skip                                   1
# ECV Done?                              1
# patient_race___7                       1
# patient_race___9                       1
# baby_status_1                          1
# baby_gender_2                          0
# baby_status_2                          0
# gravida_prev_preg_5                    1
# para_prev_preg_5                       1
# term_prev_preg_5                       1
# preterm_prev_preg_4                    1
# preterm_prev_preg_5                    1
# pregnancy_episode_delivery_complete    1
# ecv_fetal_abnormal_2                   1
# ecv_successful_3                       1
# ecv_fetal_abnormal_3                   0
# ecv_successful_4                       1
# ecv_fetal_abnormal_4                   0
# ecv_complete                           1
# dtype: int64

# %%
exportable_records_by_pt["age_delivery"] // 5
# Out:
# subject_id
# 1      6
# 2      7
# 3      5
# 5      7
# 6      7
#       ..
# 157    4
# 158    7
# 160    4
# 162    6
# 165    6
# Name: age_delivery, Length: 125, dtype: int64

# %%
max_prev_preg = "12345"

exportable_records_by_pt = proc_records_by_pt_df.drop(columns=[
    "Skip","ECV Done?",  # all ECVs not to be counted were already removed
    *[f"ecv_fetal_abnormal_{n}" for n in ecv_num_options],  # this value was not consistently reported enough to be useful
    "ecv_complete","pregnancy_episode_delivery_complete", # unsure what these columns meant, but all values are the same
    "baby_status_1", "baby_status_2", "baby_gender_2",  # twins excluded, baby status meant to be FHT abnormalities but wasn't reported enough to be useful
    "chronic_htn_before","chronic_htn_during","dm1_before","dm1_during","dm2_before","dm2_during","gestational_dm_during","preeclampsia_during", # HTN and diabetes values were not consistently reported enough to be useful
    "ultrasounds_complete", # indicates number of ultrasounds in pregnancy, not really useful
    "tobacco_use", "alcohol_use", "ill_drug_use", # this value was not consistently reported enough to be useful
    "SDP1", # redundant with SDP
    *[f"gravida_prev_preg_{n}" for n in max_prev_preg], # not useful as Gs and Ps for this pregnancy are already included
    *[f"para_prev_preg_{n}" for n in max_prev_preg], # not useful as Gs and Ps for this pregnancy are already included
    *[f"term_prev_preg_{n}" for n in max_prev_preg], # not useful as Gs and Ps for this pregnancy are already included
    *[f"preterm_prev_preg_{n}" for n in max_prev_preg], # not useful as Gs and Ps for this pregnancy are already included
    ])
exportable_records_by_pt = exportable_records_by_pt.rename(columns={
    "gravida_this_pregnancy":"gravida",
    "para_this_pregnancy":"para",
    "term_this_pregnancy":"term_preg_ct",
    "preterm_this_pregnancy":"preterm_preg_ct",
    "baby_gender_1":"baby_gender",
    "language_c":"language",
    })
# Convert age to 5 year intervals (eg 33 to 30-34)
exportable_records_by_pt.insert(exportable_records_by_pt.columns.get_loc("age_delivery"),
                                "mat_age_delivery",
                                (exportable_records_by_pt["age_delivery"] // 5)*5
                                )
exportable_records_by_pt["mat_age_delivery"] = exportable_records_by_pt["mat_age_delivery"].astype(str) + "-" + (exportable_records_by_pt["mat_age_delivery"]+4).astype(str)
exportable_records_by_pt = exportable_records_by_pt.drop(columns=["age_delivery"])


with pd.option_context("display.max_columns", None):
    display(exportable_records_by_pt)
# Out:
#            Presentation Brief Presentation Detail       Placenta Location  \
# subject_id
# 1                      Breech               frank  posterior left lateral
# 2                      Breech                None          posterior high
# 3                  Transverse                None                anterior
# 5                      Breech            footling          anterior right
# 6                      Breech               frank          posterior high
# ...                       ...                 ...                     ...
# 157                    Breech                None        posterior fundal
# 158                   Oblique          transverse            anterior mid
# 160                    Breech                None           posterior mid
# 162                    Breech               frank           posterior mid
# 165                    Breech                None          posterior high
#
#            Placenta Grade  AFI equiv    AFI          SDP          Fetal Spine  \
# subject_id
# 1               Grade 1-2      14.46  14.46          NaN                  NaN
# 2               Grade 1-2      10.76  10.76  3.33 x 3.05                  NaN
# 3                 Grade 2      20.90  20.90          NaN                  NaN
# 5                 Grade 1      12.17  12.17  5.84 x 3.01  Spine to maternal R
# 6                 Grade 1       6.71   6.71  2.69 x 2.37                  NaN
# ...                   ...        ...    ...          ...                  ...
# 157               Grade 2      15.44  15.44          NaN                  NaN
# 158               Grade 2       9.49   9.49          NaN                  NaN
# 160             Grade 1-2      16.45  16.45          NaN                  NaN
# 162               Grade 2      10.70  10.70          NaN                  NaN
# 165             Grade 1-2      26.26  26.26          NaN                  NaN
#
#             US EFW (g)  US EFW (%)  ECV EFW (g)  Delivery EFW (g) ECV GA  \
# subject_id
# 1               2563.0        0.36  2963.197413       2963.197413    262
# 2               2877.0        0.68  3106.886213       3565.104487    260
# 3               2877.0        0.68  3170.023699       3931.746889    259
# 5               3335.0        0.71  3265.582284       3719.951169    261
# 6               2736.0        0.29  3336.493981       3365.044654    277
# ...                ...         ...          ...               ...    ...
# 157             2953.0        0.49  2939.209513       3644.737166    260
# 158             2795.0        0.40  3513.125206       3513.125206    282
# 160             3030.0        0.36  3059.062238       3236.478595    268
# 162             2601.0        0.12  2750.091060       3017.054676    264
# 165             2851.0        0.55  2991.707066       3023.511276    260
#
#            ECV to Delivery (days)  Delivery GA Delivery Type Brief  \
# subject_id
# 1                               0          262           C-Section
# 2                              14          274             Vaginal
# 3                              24          283             Vaginal
# 5                              14          275           C-Section
# 6                               1          278             Vaginal
# ...                           ...          ...                 ...
# 157                            23          283             Vaginal
# 158                             0          282           C-Section
# 160                             6          274           C-Section
# 162                            10          274           C-Section
# 165                             1          261             Vaginal
#
#            Delivery Type Detail Delivery Type Ct  \
# subject_id
# 1                Low Transverse          Primary
# 2                   Spontaneous              NaN
# 3                   Spontaneous              NaN
# 5                Low Transverse          Primary
# 6                   Spontaneous              NaN
# ...                         ...              ...
# 157                 Spontaneous              NaN
# 158              Low Transverse           Repeat
# 160              Low Transverse              NaN
# 162              Low Transverse          Primary
# 165                 Spontaneous              NaN
#
#                                                         Notes  \
# subject_id
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# ...                                                       ...
# 157                                                       NaN
# 158         Successful ECV with epidural for oblique. Ulti...
# 160                                                       NaN
# 162                                                       NaN
# 165                                                       NaN
#
#            mat_age_delivery  first_bmi  first_weight  last_bmi  delivery_bmi  \
# subject_id
# 1                     30-34      21.49    118.000000     21.49           NaN
# 2                     35-39      27.37    180.000000     27.37           NaN
# 3                     25-29        NaN           NaN       NaN           NaN
# 5                     35-39      27.57    174.000000     30.34         30.34
# 6                     35-39      18.18    102.624375     23.91         23.91
# ...                     ...        ...           ...       ...           ...
# 157                   20-24      24.68    136.000000     24.89         24.89
# 158                   35-39      27.83    137.800000     31.71         31.71
# 160                   20-24      27.44    170.000000     32.49         32.49
# 162                   30-34      23.24    143.000000     24.24         24.24
# 165                   30-34      22.46    143.400000     25.11         25.11
#
#             delivery_weight        twg  ethnicity  patient_race___1  \
# subject_id
# 1                    143.00  25.000000         12                 1
# 2                    200.00  20.000000         12                 1
# 3                       NaN        NaN         12                 1
# 5                    188.00  14.000000         12                 1
# 6                    135.00  32.375625         12                 1
# ...                     ...        ...        ...               ...
# 157                  145.00   9.000000         12                 0
# 158                  157.00  19.200000         12                 0
# 160                  201.20  31.200000         12                 0
# 162                  150.19   7.190000         11                 0
# 165                  160.00  16.600000         12                 1
#
#             patient_race___2  patient_race___3  patient_race___4  \
# subject_id
# 1                          0                 0                 0
# 2                          0                 0                 0
# 3                          0                 0                 0
# 5                          0                 0                 0
# 6                          0                 0                 0
# ...                      ...               ...               ...
# 157                        1                 0                 0
# 158                        1                 0                 0
# 160                        1                 0                 0
# 162                        0                 0                 0
# 165                        0                 0                 0
#
#             patient_race___5  patient_race___6  patient_race___7  \
# subject_id
# 1                          0                 0                 0
# 2                          0                 0                 0
# 3                          0                 0                 0
# 5                          0                 0                 0
# 6                          0                 0                 0
# ...                      ...               ...               ...
# 157                        0                 0                 0
# 158                        0                 0                 0
# 160                        0                 0                 0
# 162                        1                 0                 0
# 165                        0                 0                 0
#
#             patient_race___8  patient_race___9  language  \
# subject_id
# 1                          0                 0         1
# 2                          0                 0         1
# 3                          0                 0         1
# 5                          0                 0         1
# 6                          0                 0         1
# ...                      ...               ...       ...
# 157                        0                 0         1
# 158                        0                 0         1
# 160                        0                 0         1
# 162                        0                 0         1
# 165                        0                 0         1
#
#             interpreter_needed_yn  baby_gender  gravida  para  term_preg_ct  \
# subject_id
# 1                             0.0            2        1     0             0
# 2                             0.0            1        4     3             3
# 3                             NaN            2        3     2             2
# 5                             0.0            2        3     2             2
# 6                             0.0            2        3     2             2
# ...                           ...          ...      ...   ...           ...
# 157                           0.0            1        4     1             1
# 158                           0.0            1        4     2             1
# 160                           0.0            1        2     0             0
# 162                           0.0            2        1     0             0
# 165                           0.0            1        2     1             1
#
#             preterm_preg_ct  rupture_membranes  ecv_successful_1  \
# subject_id
# 1                         0                1.0               1.0
# 2                         0                3.0               1.0
# 3                         0                5.0               0.0
# 5                         0                3.0               0.0
# 6                         0                1.0               1.0
# ...                     ...                ...               ...
# 157                       0                1.0               1.0
# 158                       1                1.0               1.0
# 160                       0                NaN               1.0
# 162                       0                NaN               0.0
# 165                       0                1.0               1.0
#
#             ecv_successful_2  ecv_successful_3  ecv_successful_4  ecv_tries
# subject_id
# 1                        NaN               NaN               NaN          1
# 2                        NaN               NaN               NaN          1
# 3                        NaN               NaN               NaN          1
# 5                        NaN               NaN               NaN          1
# 6                        NaN               NaN               NaN          1
# ...                      ...               ...               ...        ...
# 157                      NaN               NaN               NaN          1
# 158                      NaN               NaN               NaN          1
# 160                      NaN               NaN               NaN          1
# 162                      NaN               NaN               NaN          1
# 165                      NaN               NaN               NaN          1
#
# [125 rows x 49 columns]

# %% [markdown]
# ### Save processed dfs for future running

# %%
all_records_by_pt_df.to_csv(  "data/02_processed/all_records_by_pt_df"+".csv")
all_records_by_pt_df.to_excel("data/02_processed/all_records_by_pt_df"+".xlsx")
all_records_by_pt_df.to_pickle("data/02_processed/all_records_by_pt_df"+".pkl")

proc_records_by_pt_df.to_csv(  "data/02_processed/proc_records_by_pt_df"+".csv")
proc_records_by_pt_df.to_excel("data/02_processed/proc_records_by_pt_df"+".xlsx")
proc_records_by_pt_df.to_pickle("data/02_processed/proc_records_by_pt_df"+".pkl")

proc_records_by_ecv_df.to_csv(  "data/02_processed/proc_records_by_ecv_df"+".csv")
proc_records_by_ecv_df.to_excel("data/02_processed/proc_records_by_ecv_df"+".xlsx")
proc_records_by_ecv_df.to_pickle("data/02_processed/proc_records_by_ecv_df"+".pkl")

exportable_records_by_pt.to_csv(  "data/02_processed/exportable_records_by_pt"+".csv")
exportable_records_by_pt.to_excel("data/02_processed/exportable_records_by_pt"+".xlsx")
exportable_records_by_pt.to_pickle("data/02_processed/exportable_records_by_pt"+".pkl")
